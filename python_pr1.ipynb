# %% [markdown]
# # Практична робота №1
# **Тема:** Введення та виведення даних, математичні обчислення.
#
# ## Мета роботи
# 1. Ознайомитися з основами роботи в середовищі програмування Python.
# 2. Навчитися запускати прості програми та зберігати результати роботи.
# 3. Освоїти базові операції введення, виведення та обчислення в Python.
# 4. Навчитися надавати результати  у зручному форматі.

# %% [markdown]
# **Завдання 1**
#
# Напишіть програму, яка знаходить суму двох цілих чисел
#
#
# Виконайте приклад нижче

# %%
# Ця програма зчитує два числа і виводить їхню суму:
a=int(input('1 число: '))
b=int(input('2 число'))
print(f'сума чисел {a} та {b} це {a+b}')

# %% [markdown]
# **Завдання для самостійного виконання 1**
#
# Напишіть програму, яка зчитує 2 числа та виводить їхню різницю, добуток та частку

# %%
a = float(input("1 число: "))
b = float(input("2 число: "))

print(f"Різниця чисел {a} та {b}: {a - b}")
print(f"Добуток чисел {a} та {b}: {a * b}")
print(f"Частка чисел {a} та {b}: {a / b}")

# %% [markdown]
# **Завдання 2**
#
# Напишить програму, яка запитує ім'я користувача, його вік та сповіщає користувача, скільки років йому буде наступного року
#
# Виконайте приклад нижче:

# %%
name = input("Введіть ім'я: ")
age = int(input("Введіть вік: "))

print(f"{name}, наступного року вам буде {age + 1} років")

# %% [markdown]
# **Завдання для самостійного виконання 2**
#
# Напишіть програму, яка запитує ім'я користувача та рік його народження, а також, скільки залишилось до 60 років. Потім виводить все у f-рядку.

# %%
from datetime import date

name = input("Введіть ім'я: ")
birth_year = int(input("Введіть рік народження: "))

current_year = date.today().year
age = current_year - birth_year
years_left = 60 - age

print(f"{name}, вам {age} років. До 60 років залишилось {years_left} років.")

# %% [markdown]
# **Завдання 3**
#
# Напишіть програму, яка Обчисліть середнє трьох чисел.
#
# Виконайте приклад нижче

# %%
a = float(input())
b = float(input())
c = float(input())
print("Середнє:", (a + b + c) / 3)

# %% [markdown]
# **Завдання для самостійного виконання 3**
#
# Обчислити середньоквадратичне трьох чисел ![image.png](data:image/png;base64,...)
#
# На початку потрібно імпортувати бібліотеку математичних функцій
#
# import math
#
# Потім використовувати конструкцію
#
# rms = math.sqrt((вираз))

# %%
import math

a = float(input("1 число: "))
b = float(input("2 число: "))
c = float(input("3 число: "))

rms = math.sqrt((a ** 2 + b ** 2 + c ** 2) / 3)

print(f"Середньоквадратичне трьох чисел: {rms:.2f}")

# %% [markdown]
# **Завдання 4**
#
# Введіть температуру в Цельсіях. Переведіть у Фаренгейти.
#
# Виконайте приклад нижче:

# %%
# Ввід температури в Цельсіях
celsius = float(input("Введіть температуру в Цельсіях: "))

# Формула перетворення
fahrenheit = celsius * 9 / 5 + 32

# Вивід результату
print("Температура у Фаренгейтах:", round(fahrenheit, 2))

# %% [markdown]
# **Завдання для самостійного виконання 4**
#
# Введіть довжину у кілометрах. Переведіть у мілі

# %%
kilometers = float(input("Введіть довжину у кілометрах: "))

miles = kilometers * 0.621371

print(f"{kilometers} км = {miles:.2f} миль")

# %% [markdown]
# **Завдання 5**
#
# Введіть кількість днів. Переведіть у тижні та дні
#
# Виконайте код нижче:

# %%
days = int(input("Введіть кількість днів: "))

weeks = days // 7
remaining_days = days % 7

print(f"{days} днів = {weeks} тижнів і {remaining_days} днів")

# %% [markdown]
# **Завдання для самостійного виконання 5**
#
# Введіть кількість секунд. Переведіть у години, хвилини та секунди

# %%
total_seconds = int(input("Введіть кількість секунд: "))

hours = total_seconds // 3600
minutes = (total_seconds % 3600) // 60
seconds = total_seconds % 60

print(f"{total_seconds} секунд = {hours} годин, {minutes} хвилин і {seconds} секунд")

# %% [markdown]
# **Завдання 6**
#
# Напишить програму, яка генерує три випадкових числа від 1 до 10 та виводить їх з 2 знаками після коми у f-рядку
#
# Виконайте приклад нижче

# %%
import random

# Генерація трьох випадкових чисел
a = random.uniform(1, 10)
b = random.uniform(1, 10)
c = random.uniform(1, 10)

# Вивід з округленням до 2 знаків
print(f"Числа: {a:.2f}, {b:.2f}, {c:.2f}")

# %% [markdown]
# **Завдання для самостійного виконання 6**
#
# Згенеруйте два випадкових цілих числа від 1 до 10 та виведіть суму їх квадратів.

# %%
import random

a = random.randint(1, 10)
b = random.randint(1, 10)

sum_of_squares = a ** 2 + b ** 2

print(f"Перше число: {a}")
print(f"Друге число: {b}")
print(f"Сума квадратів: {sum_of_squares}")

# %% [markdown]
# **Завдання для самостійного виконання 7**
#
# Напишіть програму, яка отримує на вхід 3 числа – години, хвилини, секунди та виводить результат у форматі гг:хх:сс

# %%
hours = int(input("Введіть години: "))
minutes = int(input("Введіть хвилини: "))
seconds = int(input("Введіть секунди: "))

print(f"{hours:02d}:{minutes:02d}:{seconds:02d}")

# %% [markdown]
# **Завдання для самостійного виконання 8**
#
# Напиши програму, яка отримує на вхід діаметр та обчислює та виводить у зрозумілому форматі довжину окружності та площу круга

# %%
import math

diameter = float(input("Введіть діаметр круга: "))

radius = diameter / 2
circumference = math.pi * diameter
area = math.pi * radius ** 2

print(f"Діаметр круга: {diameter}")
print(f"Довжина окружності: {circumference:.2f}")
print(f"Площа круга: {area:.2f}")

# %% [markdown]
# **Завдання для самостійного виконання 9**
#
# Напишіть програму, яка отримує на вхід число від 420 до 540 (оптимальна тривалість сну у хвилинах) і допомагає користувачеві визначити, на який час (у форматі «години:хвилини») потрібно встановити дзвінок будильника. Відлік часу починається з півночі

# %%
sleep_minutes = int(input("Введіть тривалість сну у хвилинах від 420 до 540: "))

hours = sleep_minutes // 60
minutes = sleep_minutes % 60

print(f"Будильник потрібно встановити на {hours:02d}:{minutes:02d}")

# %% [markdown]
# **Завдання для самостійного виконання 10**
#
# Конвертуйте долари в євро за заданим курсом.

# %%
dollars = float(input("Введіть суму в доларах: "))
rate = float(input("Введіть курс: скільки євро за 1 долар: "))

euros = dollars * rate

print(f"{dollars:.2f} доларів = {euros:.2f} євро")

# %% [markdown]
# **ІДЗ**
#
# **Виконайте завдання свого варіанту**
#
# 1. Площа та периметр прямокутника по двом сторонам.
#
# 2. Об'єм куба по стороні.
#
# 3. Площа трикутника за основою та висотою
#
# 4. Відстань між двома точками на осі X.Координата першої точки x1, координата другої точки x2.
#
# 5. Вартість покупки по ціні одиниці та кількості одиниць
#
# 6. Шлях швидкістю об'єкта v, часу руху t.
#
# 7. Квадрат числа та чисел на одницю меншого та на одиницю більшого.
#
# 8. Вартість палива.Пройдена відстань, витрата палива на 100 км, ціна палива за літр.
#
# 9. Обмін валют. Сума в гривнях G, курс обміну R.
#
# 10. Об'єм конуса.Радіус основи, висота.
#
# 11. Периметр трикутника.Довжини трьох сторін a,b,c.
#
# 12. Підвищення зарплати. Початкова зарплата Z, відсоток підвищення P.
#
# 13. Площа трапеції.Довжини основ a,b та висота h.
#
# 14. Залишок від ділення та ціла частина.Два цілих числа A та B.Вивести цілу частину A//B та залишок A%B
#
# 15. Площа поверхні кулі.Радіус кулі.

# %%
distance = float(input("Введіть пройдену відстань у км: "))
consumption = float(input("Введіть витрату палива на 100 км: "))
price = float(input("Введіть ціну палива за 1 літр: "))

fuel_used = distance * consumption / 100
total_cost = fuel_used * price

print(f"Пройдена відстань: {distance:.2f} км")
print(f"Витрата палива: {consumption:.2f} л/100 км")
print(f"Використано палива: {fuel_used:.2f} л")
print(f"Вартість палива: {total_cost:.2f}")
