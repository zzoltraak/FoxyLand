# %% [markdown]
# # Практична робота №7
# **Тема:** ООП у Python. Інкапсуляція та успадкування
#
# ## Мета роботи
# 1. Ознайомитися з можливостями Python у парадигмі ООП.

# %% [markdown]
# **Завдання 1**
#
# Напишіть клас MusicAlbum, який має:
# Атрибути title, artist, release_year, genre, tracklist (назва, виконавець, рік виходу, жанр, список треків).
# Метод play_random_track() для виведення випадкової назви пісні.
#
#
#
# Виконайте приклад нижче

# %%
import random

class MusicAlbum:
    """
    Представляє музичний альбом з його основними характеристиками
    та можливістю відтворення випадкового треку.
    """

    def __init__(self, title, artist, release_year, genre, tracklist):
        """
        Конструктор для ініціалізації атрибутів альбому.

        :param title: Назва альбому (str).
        :param artist: Виконавець альбому (str).
        :param release_year: Рік виходу альбому (int).
        :param genre: Жанр альбому (str).
        :param tracklist: Список треків альбому (list of str).
        """
        self.title = title
        self.artist = artist
        self.release_year = release_year
        self.genre = genre
        self.tracklist = tracklist

    def play_random_track(self):
        """
        Вибирає та виводить випадкову назву пісні зі списку треків (tracklist).
        """
        # Перевірка, чи список треків не порожній
        if not self.tracklist:
            print(f"Альбом '{self.title}' не містить треків.")
            return

        # Використання функції random.choice() для вибору випадкового елемента зі списку
        random_track = random.choice(self.tracklist)

        print("Зараз грає випадковий трек:")
        print(f"Альбом: {self.title} - Виконавець: {self.artist}")
        print(f"Трек: **{random_track}**")

# ----------------- Приклад використання класу -----------------

# Створення екземпляра класу MusicAlbum
my_album = MusicAlbum(
    title="The Dark Side of the Moon",
    artist="Pink Floyd",
    release_year=1973,
    genre="Progressive Rock",
    tracklist=[
        "Speak to Me",
        "Breathe (In the Air)",
        "On the Run",
        "Time",
        "The Great Gig in the Sky",
        "Money",
        "Us and Them",
        "Any Colour You Like",
        "Brain Damage",
        "Eclipse"
    ]
)

print(f"--- Інформація про альбом ---")
print(f"Назва: {my_album.title}")
print(f"Виконавець: {my_album.artist}")
print(f"Треків у списку: {len(my_album.tracklist)}")
print("-----------------------------\n")

# Виклик методу для відтворення випадкового треку
my_album.play_random_track()

print("\n")

# Виклик методу ще раз для демонстрації випадковості
my_album.play_random_track()
# Out:
# --- Інформація про альбом ---
# Назва: The Dark Side of the Moon
# Виконавець: Pink Floyd
# Треків у списку: 10
# -----------------------------
#
# Зараз грає випадковий трек:
# Альбом: The Dark Side of the Moon - Виконавець: Pink Floyd
# Трек: **Any Colour You Like**
#
#
# Зараз грає випадковий трек:
# Альбом: The Dark Side of the Moon - Виконавець: Pink Floyd
# Трек: **Money**

# %% [markdown]
# **Завдання для самостійного виконання 1**
#
#
# Створіть клас Student, який має:
# атрибути name, age, grade, scores (ім'я, вік, клас, оцінки);
# метод average_score - для обчислення середнього балу успішності.
# Використайте клас для створення екземпляру студента та обчислення його середнього балу.

# %%
class Student:
    def __init__(self, name, age, grade, scores):
        self.name = name
        self.age = age
        self.grade = grade
        self.scores = scores

    def average_score(self):
        if len(self.scores) == 0:
            return 0
        return sum(self.scores) / len(self.scores)


student = Student("Єкатерина Свирида", 16, "11-А", [10, 12, 9, 11, 9])

print("--- Інформація про студента ---")
print(f"Ім'я: {student.name}")
print(f"Вік: {student.age}")
print(f"Клас: {student.grade}")
print(f"Оцінки: {student.scores}")
print(f"Середній бал: {student.average_score():.2f}")
# Out:
# --- Інформація про студента ---
# Ім'я: Єкатерина Свирида
# Вік: 16
# Клас: 11-А
# Оцінки: [10, 12, 9, 11, 9]
# Середній бал: 10.20

# %% [markdown]
# **Завдання 2**
#
# Напишіть суперклас Publisher (видавництво) та два підкласи BookPublisher (книжкове видавництво) та NewspaperPublisher (газетне видавництво).
#
# Батьківський клас Publisher має два атрибути name і location (назва, розташування) та два методи:
#
# get_info(self) – надає інформацію про назву та розташування видавництва;
#
# publish(self, message) – виводить інформацію про видання, що міститься у друку.
#
# Підкласи BookPublisher і NewspaperPublisher використовують метод super().
# __init__(name, location) суперкласу для виведення інформації про свої назви та розташування, і крім того, мають власні атрибути:
#
# BookPublisher - num_authors (кількість авторів).
#
# NewspaperPublisher - num_pages (кількість сторінок в газеті).
#
#
# Виконайте приклад нижче:

# %%
class Publisher:
    """
    Суперклас, що представляє видавництво.
    """
    def __init__(self, name, location):
        """
        Конструктор для ініціалізації назви та розташування видавництва.
        """
        self.name = name
        self.location = location
        print(f"Створено видавництво: {self.name} ({self.location})")

    def get_info(self):
        """
        Повертає рядок з інформацією про назву та розташування видавництва.
        """
        return f"Видавництво: {self.name}, Розташування: {self.location}"

    def publish(self, message):
        """
        Виводить інформацію про видання.
        """
        print(f"[{self.name}] Приймає до друку повідомлення: '{message}'")


class BookPublisher(Publisher):
    """
    Підклас для книжкового видавництва. Додає атрибут num_authors.
    """
    def __init__(self, name, location, num_authors):
        # Виклик конструктора батьківського класу для ініціалізації name та location
        super().__init__(name, location)
        self.num_authors = num_authors

    def get_info(self):
        """
        Розширення методу get_info() батьківського класу.
        """
        # Використовуємо метод батьківського класу для базової інформації
        base_info = super().get_info()
        return f"{base_info}, Тип: Книжкове, Кількість авторів: {self.num_authors}"

    def publish(self, title):
        """
        Перевизначення методу publish() для контексту книги.
        """
        super().publish(f"Нова книга '{title}'")


class NewspaperPublisher(Publisher):
    """
    Підклас для газетного видавництва. Додає атрибут num_pages.
    """
    def __init__(self, name, location, num_pages):
        # Виклик конструктора батьківського класу для ініціалізації name та location
        super().__init__(name, location)
        self.num_pages = num_pages

    def get_info(self):
        """
        Розширення методу get_info() батьківського класу.
        """
        base_info = super().get_info()
        return f"{base_info}, Тип: Газетне, Кількість сторінок: {self.num_pages}"

    def publish(self, edition_date):
        """
        Перевизначення методу publish() для контексту газети.
        """
        super().publish(f"Газета за {edition_date} ({self.num_pages} сторінок)")

# Створення екземпляра книжкового видавництва
book_publisher = BookPublisher(
    name="Книжковий Клуб",
    location="Київ",
    num_authors=150
)

# Створення екземпляра газетного видавництва
newspaper_publisher = NewspaperPublisher(
    name="Щоденні Новини",
    location="Львів",
    num_pages=16
)

print("\n--- Інформація та публікації ---")

# Виклик методів BookPublisher
print(book_publisher.get_info())
book_publisher.publish("Майбутнє штучного інтелекту")

print("-" * 20)

# Виклик методів NewspaperPublisher
print(newspaper_publisher.get_info())
newspaper_publisher.publish("2025-11-17")
# Out:
# Створено видавництво: Книжковий Клуб (Київ)
# Створено видавництво: Щоденні Новини (Львів)
#
# --- Інформація та публікації ---
# Видавництво: Книжковий Клуб, Розташування: Київ, Тип: Книжкове, Кількість авторів: 150
# [Книжковий Клуб] Приймає до друку повідомлення: 'Нова книга 'Майбутнє штучного інтелекту''
# --------------------
# Видавництво: Щоденні Новини, Розташування: Львів, Тип: Газетне, Кількість сторінок: 16
# [Щоденні Новини] Приймає до друку повідомлення: 'Газета за 2025-11-17 (16 сторінок)'

# %% [markdown]
# **Завдання для самостійного виконання 2**
#
# Напишіть клас Animal, що володіє властивостями name, species, legs, в яких зберігаються дані про прізвисько, вид і кількість ніг тварини. Клас також повинен мати два методи – voice() та move(), які повідомляють про те, що тварина подає голос та рухається.
#
# Створіть два підкласи – Dog та Bird.
#
# Підклас Dog має атрибут breed (порода) та метод bark(), який повідомляє про те, що собака гавкає.
#
# Підклас Bird має властивість wingspan (розмах крил) і метод fly(), який повідомляє про політ птиці.

# %%
class Animal:
    def __init__(self, name, species, legs):
        self.name = name
        self.species = species
        self.legs = legs

    def voice(self):
        print(f"{self.name} подає голос.")

    def move(self):
        print(f"{self.name} рухається на {self.legs} ногах.")


class Dog(Animal):
    def __init__(self, name, species, legs, breed):
        super().__init__(name, species, legs)
        self.breed = breed

    def bark(self):
        print(f"{self.name} гавкає. Порода: {self.breed}.")


class Bird(Animal):
    def __init__(self, name, species, legs, wingspan):
        super().__init__(name, species, legs)
        self.wingspan = wingspan

    def fly(self):
        print(f"{self.name} літає. Розмах крил: {self.wingspan} см.")


dog = Dog("Роня", "Собака", 4, "Померанський шпиц")
bird = Bird("Кузя", "Папуга", 2, 30)

print("--- Собака ---")
print(f"Ім'я: {dog.name}")
print(f"Вид: {dog.species}")
print(f"Кількість ніг: {dog.legs}")
print(f"Порода: {dog.breed}")
dog.voice()
dog.move()
dog.bark()

print("\n--- Птах ---")
print(f"Ім'я: {bird.name}")
print(f"Вид: {bird.species}")
print(f"Кількість ніг: {bird.legs}")
print(f"Розмах крил: {bird.wingspan} см")
bird.voice()
bird.move()
bird.fly()
# Out:
# --- Собака ---
# Ім'я: Роня
# Вид: Собака
# Кількість ніг: 4
# Порода: Померанський шпиц
# Роня подає голос.
# Роня рухається на 4 ногах.
# Роня гавкає. Порода: Померанський шпиц.
#
# --- Птах ---
# Ім'я: Кузя
# Вид: Папуга
# Кількість ніг: 2
# Розмах крил: 30 см
# Кузя подає голос.
# Кузя рухається на 2 ногах.
# Кузя літає. Розмах крил: 30 см.

# %% [markdown]
# **Індивідуальне завдання. **
#
# Виконайте одну задачу свого варіанту
#
# 1: Банківський рахунок
#
# Створіть клас BankAccount з прихованими атрибутами balance та owner. Реалізуйте методи для внесення та зняття коштів з рахунку. Від цього класу створіть клас SavingsAccount, який додає метод для нарахування відсотків.
#
#
# 2: Вимірювальний прилад
#
# Створіть клас MeasurementDevice з прихованими атрибутами name і value. Реалізуйте методи для читання та запису значення. Від цього класу створіть клас Thermometer, який додає метод для перевірки, чи температура є в нормальному діапазоні.
#
#
# 3: Книга
#
# Створіть клас Book з прихованими атрибутами title і author. Додайте методи для отримання та зміни цих атрибутів. Від класу Book успадкуйте клас EBook, який додасть метод для завантаження книги.
#
#
# 4: Вчитель
#
# Створіть клас Teacher з прихованими атрибутами name і subject. Реалізуйте методи для отримання і зміни цих атрибутів. Від класу Teacher створіть клас MathTeacher, який додасть метод для проведення математичного тесту.
#
#
# 5: Автомобіль
#
# Створіть клас Car з прихованими атрибутами brand і speed. Реалізуйте методи для збільшення та зменшення швидкості. Від класу Car створіть клас ElectricCar, який додасть метод для перевірки рівня заряду батареї.
#
#
# 6: Телефон
#
# Створіть клас Phone з прихованими атрибутами number і model. Реалізуйте методи для отримання та зміни цих атрибутів. Від класу Phone успадкуйте клас Smartphone, який додасть метод для встановлення додатків.
#
#
# 7: Персональний комп'ютер
#
# Створіть клас PC з прихованими атрибутами processor і ram. Реалізуйте методи для отримання і зміни цих атрибутів. Від класу PC створіть клас GamingPC, який додасть метод для перевірки сумісності з іграми.
#
#
# 8: Людина
#
# Створіть клас Person з прихованими атрибутами name і age. Реалізуйте методи для отримання та зміни цих атрибутів. Від класу Person створіть клас Student, який додасть метод для запису на курс.
#
#
# 9: Продукт
#
# Створіть клас Product з прихованими атрибутами name і price. Реалізуйте методи для отримання та зміни цих атрибутів. Від класу Product створіть клас FoodProduct, який додасть метод для встановлення терміну придатності.
#
#
# 10: Фільм
#
# Створіть клас Movie з прихованими атрибутами title і director. Реалізуйте методи для отримання і зміни цих атрибутів. Від класу Movie створіть клас Documentary, який додасть метод для встановлення тривалості.
#
#
# 11: Ресторан
#
# Створіть клас Restaurant з прихованими атрибутами name і menu. Реалізуйте методи для отримання та зміни меню. Від класу Restaurant створіть клас FastFood, який додасть метод для перевірки швидкості обслуговування.
#
#
# 12: Музичний інструмент
#
# Створіть клас Instrument з прихованими атрибутами type і brand. Реалізуйте методи для отримання та зміни цих атрибутів. Від класу Instrument створіть клас Guitar, який додасть метод для перевірки кількості струн.
#
#
# 13: Готель
#
# Створіть клас Hotel з прихованими атрибутами name і rooms. Реалізуйте методи для бронювання та скасування номерів. Від класу Hotel створіть клас Resort, який додасть метод для перевірки доступності додаткових послуг.
#
#
# Завдання 14: Спортивний інвентар
#
# Створіть клас Equipment з прихованими атрибутами type і brand. Реалізуйте методи для отримання та зміни цих атрибутів. Від класу Equipment створіть клас Football, який додасть метод для перевірки тиску м'яча.
#
#
# Завдання 15: Сад
#
# Створіть клас Garden з прихованими атрибутами size і plants. Реалізуйте методи для додавання та видалення рослин. Від класу Garden створіть клас BotanicalGarden, який додасть метод для перевірки рідкісних видів.

# %%
class Person:
    def __init__(self, name, age):
        self.__name = name
        self.__age = age

    def get_name(self):
        return self.__name

    def set_name(self, name):
        self.__name = name

    def get_age(self):
        return self.__age

    def set_age(self, age):
        self.__age = age


class Student(Person):
    def __init__(self, name, age):
        super().__init__(name, age)
        self.courses = []

    def enroll_course(self, course_name):
        self.courses.append(course_name)
        print(f"Студент {self.get_name()} записаний на курс: {course_name}")

    def get_courses(self):
        return self.courses

print("---Інформація про студента---")
student = Student("Володимир", 19)

print("Ім'я:", student.get_name())
print("Вік:", student.get_age())

print("\n---Оновлена інформація---")
student.set_name("Кирило")
student.set_age(20)

print("Нове ім'я:", student.get_name())
print("Новий вік:", student.get_age())

student.enroll_course("Програмування на мові Python")
student.enroll_course("Об’єктно-орієнтоване програмування")

print("Курси студента:", student.get_courses())
# Out:
# ---Інформація про студента---
# Ім'я: Володимир
# Вік: 19
#
# ---Оновлена інформація---
# Нове ім'я: Кирило
# Новий вік: 20
# Студент Кирило записаний на курс: Програмування на мові Python
# Студент Кирило записаний на курс: Об’єктно-орієнтоване програмування
# Курси студента: ['Програмування на мові Python', 'Об’єктно-орієнтоване програмування']
