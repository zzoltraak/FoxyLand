# %% [markdown]
# # Практична робота №3
# **Тема:** Методи роботи зі списками
#
# ## Мета роботи
# 1. Навчитися роботі з даними у вигляді списків

# %% [markdown]
# **Завдання 1**
#
# Створити списки різними способами
#
#
#
# Виконайте приклад нижче

# %%
#Створення порожнього списку
empty_list = []
print(empty_list)

#Створення списку з елементами вручну
fruits = ['apple', 'banana', 'cherry']
print(fruits)

#Створення списку за допомогою функції list()
numbers = list((1, 2, 3, 4))
print(numbers)

#Створення списку з генератором списку (list comprehension)
squares = [x**2 for x in range(5)]
print(squares)

#Створення списку з функцією range()
even_numbers = list(range(0, 10, 2))
print(even_numbers)

#Створення списку з введенням користувача
user_input = input("Введіть числа через кому: ")
user_list = user_input.split(',')
print(user_list)

#Створення списку з умовою
filtered = [x for x in range(10) if x % 2 == 0]
print(filtered)

#Створення списку з функції map()
string_numbers = ['1', '2', '3']
int_numbers = list(map(int, string_numbers))
print(int_numbers)
# Out:
# []
# ['apple', 'banana', 'cherry']
# [1, 2, 3, 4]
# [0, 1, 4, 9, 16]
# [0, 2, 4, 6, 8]
# Введіть числа через кому: 2,3,4,5
# ['2', '3', '4', '5']
# [0, 2, 4, 6, 8]
# [1, 2, 3]

# %% [markdown]
# **Завдання для самостійного виконання 1**
#
# Створіть список [3, 6, 9, 12, 15] всіми можливими способами з представлених вище

# %%
numbers1 = [3, 6, 9, 12, 15]
print(numbers1)

numbers2 = list((3, 6, 9, 12, 15))
print(numbers2)

numbers3 = [i * 3 for i in range(1, 6)]
print(numbers3)

numbers4 = list(range(3, 16, 3))
print(numbers4)

user_input = input("Введіть числа через кому: ")
numbers5 = user_input.split(',')
print(numbers5)

numbers6 = [i for i in range(1, 16) if i % 3 == 0]
print(numbers6)

numbers7 = list(map(int, ['3', '6', '9', '12', '15']))
print(numbers7)
# Out:
# [3, 6, 9, 12, 15]
# [3, 6, 9, 12, 15]
# [3, 6, 9, 12, 15]
# [3, 6, 9, 12, 15]
# Введіть числа через кому: 3, 6, 9, 12, 15
# ['3', ' 6', ' 9', ' 12', ' 15']
# [3, 6, 9, 12, 15]
# [3, 6, 9, 12, 15]

# %% [markdown]
# **Завдання 2**
#
# Напишіть програму, яка отримує на вхід рядок, вибирає з неї всі числа та виводить:
#
# мінімальне число;
#
# максимальне число;
#
# суму всіх чисел.
#
# Виконайте приклад нижче:

# %%
# Введення рядка
text = input("Введіть рядок: ")

# Створення списку лише з цифр
digits = [int(char) for char in text if char.isdigit()]

print("Мінімальна цифра:", min(digits))
print("Максимальна цифра:", max(digits))
print("Сума всіх цифр:", sum(digits))

# %% [markdown]
# **Завдання для самостійного виконання 2**
#
# Виправ програму так, щоб вона відбирала лише символи (не цифри) та рахувала їх кількість

# %%
text = input("Введіть рядок: ")

symbols = [char for char in text if not char.isdigit()]

print("Символи, які не є цифрами:", ''.join(symbols))
print("Кількість символів, які не є цифрами:", len(symbols))
# Out:
# Введіть рядок: 4+а
# Символи, які не є цифрами: +а
# Кількість символів, які не є цифрами: 2

# %% [markdown]
# **Завдання 3**
#
# Напишіть програму, яка:
#
# отримує на вхід рядок, що складається з розділених пробілами цифр;
#
# перетворює символи на цілі числа;
#
# формує з чисел список, не включаючи до нього цифри, що зустрічаються у вихідному рядку лише 1 раз;
#
# виводить список без дужок.
#
#
# Виконайте приклад нижче

# %%
# Введення рядка з цифрами через пробіл
text = input("Введіть цифри через пробіл: ")

# Перетворення на список цілих чисел
numbers = list(map(int, text.split()))

# Формування списку без унікальних елементів
filtered = [num for num in numbers if numbers.count(num) > 1]

# Виведення списку без дужок
print(*filtered)

# %% [markdown]
# **Завдання для самостійного виконання 3**
#
# Виправ програму так, щоб рядок вводився не через пробіли, а через коми та визналося середнє значення введених цифр

# %%
text = input("Введіть цифри через кому: ")

numbers = list(map(int, text.split(',')))
average = sum(numbers) / len(numbers) if numbers else 0

print("Середнє значення:", average)
# Out:
# Введіть цифри через кому: 5,7,9
# Середнє значення: 7.0

# %% [markdown]
# **Завдання 4**
#
# Напишіть програму, яка:
#
# отримує на вхід рядок чисел, розділених комами;
#
# формує з чисел два списки – з парними та непарними числами;
#
# виводить списки без дужок на окремих рядках.
#
#
# Виконайте приклад нижче:

# %%
# Введення рядка чисел через кому
text = input("Введіть числа через кому: ")

# Перетворення на список цілих чисел
numbers = list(map(int, text.split(',')))

# Формування списків парних та непарних чисел
even = [num for num in numbers if num % 2 == 0]
odd = [num for num in numbers if num % 2 != 0]

# Виведення списків без дужок
print(*even)
print(*odd)

# %% [markdown]
# **Завдання для самостійного виконання 4**
#
# Виправ програму так, щоб вводились та розділювались на два списки позитивні та негативні числа.

# %%
text = input("Введіть числа через кому: ")

numbers = list(map(int, text.split(',')))

positive = [num for num in numbers if num > 0]
negative = [num for num in numbers if num < 0]

print("Додатні числа:", *positive)
print("Від’ємні числа:", *negative)
# Out:
# Введіть числа через кому: 7,-9,3,-4
# Додатні числа: 7 3
# Від’ємні числа: -9 -4

# %% [markdown]
# **Завдання 5**
#
# Напишіть програму, яка:
#
# Напишіть програму, яка:
#
# отримує на вхід рядок, що містить (у будь-якій позиції) символ #;
#
# знаходить та видаляє # за індексом;
#
# виводить виправлений рядок та його найдовше слово.
#
#
#
# Виконайте код нижче:

# %%
#Введення рядка
text = input("Введіть рядок з символом #: ")

# Видалення символа # (лише першого входження)
index = text.index('#')
text = text[:index] + text[index+1:]

# Виведення виправленого рядка
print("Виправлений рядок:", text)

# Пошук найдовшого слова
words = text.split()
longest = max(words, key=len)

print("Найдовше слово:", longest)

# %% [markdown]
# **Завдання для самостійного виконання 5**
#
# Виправ програму так, щоб вона видаляла найдовше слово у введеному рядку

# %%
text = input("Введіть рядок: ")

words = text.split()

if words:
    longest = max(words, key=len)
    words.remove(longest)
    result = ' '.join(words)
else:
    result = ''

print("Строка без самого длинного слова:", result)
# Out:
# Введіть рядок: Гарні фіалки в саду
# Рядок без найдовшого слова: Гарні в саду

# %% [markdown]
# **Завдання 6**
#
# Напишіть програму, яка:
#
# приймає на вхід рядок, що складається із випадкових слів;
#
# відкидає слова, де є не літерні символи;
#
# переставляє слова у порядку зростання їх довжини;
#
# виводить на екран слова у стовпчик, без лапок.
#
# Виконайте приклад нижче:

# %%
# Введення рядка
text = input("Введіть рядок зі словами: ")

# Розбиття на слова
words = text.split()

# Відбір лише слів, що складаються з літер (без цифр, знаків тощо)
letter_words = [word for word in words if word.isalpha()]

# Сортування за довжиною
sorted_words = sorted(letter_words, key=len)

# Виведення у стовпчик
print(*sorted_words,sep="\n" )

# %% [markdown]
# **Завдання для самостійного виконання 6**
#
# Виправ програму так, щоб вона видаляла всі слова, які  не містять цифри

# %%
text = input("Введіть рядок зі словами: ")

words = text.split()

words_with_digits = [word for word in words if any(char.isdigit() for char in word)]

print(*words_with_digits, sep="\n")
# Out:
# Введіть рядок зі словами: 5рпар кнн
# 5рпар

# %% [markdown]
# **Завдання 7**
#
# Напишіть програму, яка отримує на вхід рядок, та формує з неї 2 списки:
#
# до першого списку входять слова, що починаються з голосних літер;
#
# другий список складається зі слів, що починаються з приголосних.
#
# Виведіть результат у два рядки без лапок та дужок.
#
# Виконай приклад нижче:

# %%
# Введення рядка
text = input("Введіть рядок зі словами: ")

# Список голосних літер (українських)
vowels = 'аеєиіїоуюяАЕЄИІЇОУЮЯ'

# Розбиття на слова
words = text.split()

# Розділення слів за першою літерою
vowel_words = [word for word in words if word[0] in vowels]
consonant_words = [word for word in words if word[0] not in vowels]

# Виведення результату без лапок і дужок
print(*vowel_words)
print(*consonant_words)

# %% [markdown]
# **Завдання для самостійного виконання 7**
#
# Додай у програму вивід списку, який містить слова, які починаються з цифр або містять цифри.

# %%
text = input("Введіть рядок зі словами: ")

vowels = 'аеєиіїоуюяАЕЄИІЇОУЮЯ'
words = text.split()

vowel_words = [word for word in words if word and word[0] in vowels]
consonant_words = [word for word in words if word and word[0].isalpha() and word[0] not in vowels]
digit_words = [word for word in words if word and (word[0].isdigit() or any(char.isdigit() for char in word))]

print("Слова, які починаються з голосних:", *vowel_words)
print("Слова, які починаються з приголосних:", *consonant_words)
print("Слова, які починаються з цифр або містять цифри:", *digit_words)
# Out:
# Введіть рядок зі словами: 45апп вап аів
# Слова, які починаються з голосних: аів
# Слова, які починаються з приголосних: вап
# Слова, які починаються з цифр або містять цифри: 45апп

# %% [markdown]
# **Завдання 8**
#
# Є два списки:
# keys = ['модель', 'ціна', 'кількість', 'розмір', 'колір', 'знижка']
#
# values = ['XXLDude', 5678.00, 57, 'XXL', 'чорний', '12%']
#
# Напишіть програму, яка об'єднує ці списки та виводить на екран список такого виду:
# модель: XXLDude

# %%
keys = ['модель', 'ціна', 'кількість', 'розмір', 'колір', 'знижка']
values = ['XXLDude', 5678.00, 57, 'XXL', 'чорний', '12%']

# Об'єднання списків у словник
product = dict(zip(keys, values))

# Виведення у форматі ключ: значення
for key, value in product.items():
    print(f"{key}: {value}")

# %% [markdown]
# **Завдання для самостійного виконання 8**
#
# Напиши свою програму, яка створює список, який містить загальну вартість окремих товарів, якщо в двох списках містяться: ціна за 1 шт деякого товару та кількість штук, які були куплені.

# %%
prices = [25.50, 10.00, 7.50, 100.39, 45.99]

quantities = [2, 5, 4, 1, 3]

total_costs = [price * quantity for price, quantity in zip(prices, quantities)]

print("Загальна вартість окремих товарів:", total_costs)
# Out:
# Загальна вартість окремих товарів: [51.0, 50.0, 30.0, 100.39, 137.97]

# %% [markdown]
# **Завдання 9**
#
# Напишіть програму, яка отримує на вхід рядок, що містить ім'я учня та його оцінки з основних предметів, та виводить середній бал успішності.

# %%
# Введення рядка
text = input("Введіть ім'я учня та його оцінки: ")

# Розбиття на частини
parts = text.split()

# Ім’я — перший елемент
name = parts[0]

# Оцінки — решта елементів, перетворені на числа
grades = list(map(float, parts[1:]))

# Обчислення середнього балу
average = sum(grades) / len(grades) if grades else 0

# Виведення результату
print(f"{name}: середній бал {average:.2f}")

# %% [markdown]
# **Завдання для самостійного виконання 9**
#
# На вхід подається рядок, який містить назву товара та його ціну в гривнях. Вивести назву, ціну в гривнях та ціну в доларах.

# %%
text = input("Введіть назву товару та його ціну в гривнях: ")

usd_rate = float(input("Введіть курс долара до гривні: "))

parts = text.split()

name = " ".join(parts[:-1])

price_uah = float(parts[-1])

price_usd = price_uah / usd_rate

print("Назва товару:", name)
print(f"Ціна в гривнях: {price_uah:.2f}")
print(f"Ціна в доларах: {price_usd:.2f}")
# Out:
# Введіть назву товару та його ціну в гривнях: Мілка, 200
# Введіть курс долара до гривні: 44
# Назва товару: Мілка,
# Ціна в гривнях: 200.00
# Ціна в доларах: 4.55

# %% [markdown]
# **Завдання 10**
#
# Іграшковий робот пересувається відповідно до команд, одержуваних у вигляді рядка виду n35 s48 e88 w33 n12 s10, де n – північ, s – південь, w – захід, e – схід, а цифри – відстань у сантиметрах. Напишіть програму для визначення x та y координат робота. Вважатимемо, що рух завжди починається з 0, 0.

# %%
# Введення команд
commands = input("Введіть команди руху робота: ")

# Розбиття на окремі команди
steps = commands.split()

# Обчислення координат без циклів
x = sum([int(i[1:]) for i in steps if i[0] == 'e']) - sum([int(i[1:]) for i in steps if i[0] == 'w'])
y = sum([int(i[1:]) for i in steps if i[0] == 'n']) - sum([int(i[1:]) for i in steps if i[0] == 's'])

# Виведення результату
print(f"x = {x}, y = {y}")
# Out:
# Введіть команди руху робота: n35 s48 e88 w33 n12 s10
# x = 55, y = -11

# %% [markdown]
# **Завдання для самостійного виконання 10**
#
# Виправ програму так, щоб вона розрахувала яку відстань в сантиметрах пройшов робот.

# %%
commands = input("Введіть команди руху робота: ")

steps = commands.split()

distance = sum([int(i[1:]) for i in steps])

print(f"Робот пройшов {distance} см")
# Out:
# Введіть команди руху робота: n35 s48 e88 w33 n12 s10
# Робот пройшов 226 см

# %% [markdown]
# **ІДЗ**
#
# **Виконайте завдання свого варіанту**
#
# 1.	Сортування: Напишіть програму, яка сортує список слів у зростаючому порядку їх довжини.
#
# 2.	Фільтрація парних/непарних чисел: Напишіть програму, яка фільтрує парні або непарні числа зі списку.
#
# 3.	Пошук середнього: Напиши програму, яка обчислює середнє арифметичне значення списку чисел.
#
# 4.	Вилучення дублікатів: Напишіть програму, яка видаляє всі дублікати зі списку.
#
# 5.	Об'єднання списків: Створіть програму, яка об'єднує два списки в один через елемент.
#
# 6.	Знаходження середнього значення: Створіть програму, яка знаходить медіану списку чисел.
#
# 7.	Пошук індексу елементу: Напишіть програму, яка повертає індекс елементу, який розташований через n елементів після  певного елемента у списку.
#
# 8.	Створення списку квадратів чисел: Напишіть програму, яка створює список квадратів чисел від 1 до заданого користувачемчисла.
#
# 9.	Розділення списку на частини: Напишіть програму, яка розділяє список на задану кількість рівних частин.
#
# 10.	Фільтрація за умовою: Напишіть програму, яка фільтрує елементи списку за певною умовою.
#
# 11.	Заміна елементів: Створіть програму, яка замінює всі входження певного елемента у списку іншим елементом.
#
# 12.	Обчислення суми елементів: Напишіть програму, яка перевіряє, що елемент є числом і обчислює суму всіх елементів у списку чисел.
#
# 13.	Перевернення слів: Створіть програму, яка перевертає порядок слів у списку рядків.
#
# 14.	Видалення елементів за індексом: Напишіть програму, яка видаляє кожний третій елемент у списку
#
# 15.	Знаходження кількості входжень: Створіть програму, яка підраховує кількість входжень певного елемента у списку.

# %%
n = int(input("Введіть число: "))

squares = [number ** 2 for number in range(1, n + 1)]

print("Список квадратів чисел:", squares)
# Out:
# Введіть число: 5
# Список квадратів чисел: [1, 4, 9, 16, 25]
