# %% [markdown]
# # Практична робота №2
# **Тема:** Методи роботи з рядками
#
# ## Мета роботи
# Навчитися працюапти з рядками у Python.

# %% [markdown]
# **Завдання 1**
#
# Напишіть програму, яка отримує на вхід рядок і виводить: кількість символів, що містяться в тексті; True або False залежно від того, чи є всі символи літерами і цифрами
#
# Виконайте приклад нижче

# %%
text = input("Введіть рядок: ")

# Кількість символів у рядку
length = len(text)

# Перевірка, чи всі символи — літери або цифри
is_alnum = text.isalnum()

print(length)
print(is_alnum)

# %% [markdown]
# **Завдання для самостійного виконання 1**
#
# Напишіть програму, яка визначає скільки знаків у введеному числі і виводить розгорнуту відповідь за допомогою f-рядка.

# %%
number = input("Введіть число: ")

count = len(number)

print(f"У введеному числі {number} міститься {count} знаків.")
# Out:
# Введіть число: 5.678
# У введеному числі 5.678 міститься 5 знаків.

# %% [markdown]
# **Завдання 2**
#
# Напишіть програму, яка отримує на вхід слово і виводить True, якщо слово є паліндромом, або False в іншому випадку. Примітка: для порівняння в Python використовується оператор ==.
#
# Виконайте приклад нижче:

# %%
# Ввід слова
word = input("Введіть слово: ")

# Перевірка на паліндром
is_palindrome = word == word[::-1]

# Вивід результату
print(is_palindrome)

# %% [markdown]
# **Завдання для самостійного виконання 2**
#
# Напиши програму, яка визначає, чи присутня у числі цифра 5

# %%
number = input("Введіть число: ")

result = "5" in number

print(result)
# Out:
# Введіть число: 64545
# True

# %% [markdown]
# **Завдання 3**
#
# Напишіть програму, яка отримує рядок з ім'ям, по батькові та прізвищем, написаними у довільному регістрі, і виводить дані в правильному форматі. Наприклад, рядок "тарас гриГороВич шевЧенко" має бути перетворений на "Тарас Григорович Шевченко".
#
# split() розбиває рядок на окремі слова.
#
# capitalize() робить першу літеру великою, а решту — маленькими.
#
# join() об’єднує слова назад у рядок з пробілами.
#
# Виконайте приклад нижче

# %%
# Ввід рядка
full_name = input("Введіть ім'я, по батькові та прізвище: ")

# Розділення на складові
parts = full_name.split()

# Перетворення кожної частини у правильний формат
formatted_parts = [part.capitalize() for part in parts]

# Об'єднання назад у рядок
formatted_name = ' '.join(formatted_parts)

# Вивід результату
print(formatted_name)

# %% [markdown]
# **Завдання для самостійного виконання 3**
#
# Напиши програму, яка переводить всі символи першого рядку в верхній регістр, а всі символи другого – в нижній.

# %%
line1 = input("Введіть перший рядок: ")
line2 = input("Введіть другий рядок: ")

print(line1.upper())
print(line2.lower())
# Out:
# Введіть перший рядок: 54645
# Введіть другий рядок: 454
# 54645
# 454

# %% [markdown]
# **Завдання 4**
#
# Є рядок 12361573928167047230472012. Напишіть програму, яка перетворює рядок на текст "один236один573928один670472304720один2".
#
# Виконайте приклад нижче:

# %%
s = "12361573928167047230472012"

# Замінюємо всі '1' на 'один'
result = s.replace('1', 'один')

print(result)

# %% [markdown]
# **Завдання для самостійного виконання 4**
#
# Заміни всі входження в текст, який містить «Сполучені Штати» на “USA”

# %%
text = input("Введіть текст: ")

result = text.replace("Сполучені Штати", "USA")

print(result)
# Out:
# Введіть текст: Сполучені Штати
# USA

# %% [markdown]
# **Завдання 5**
#
# Напишіть програму, яка послідовно отримує на вхід ім'я, по батькові, прізвище та посаду співробітника, а потім перетворює ім'я і по батькові в ініціали, додаючи посаду після коми.
#
#
# Приклад введення:
#
# Олексій
#
# Костянтинович
#
# Романов
#
# бугалтер
#
# Виведення:
#
# А. К. Романов, бугалтер
#
#
# Виконайте код нижче:

# %%
# Ввід даних
first_name = input("Ім'я: ")
patronymic = input("По батькові: ")
last_name = input("Прізвище: ")
position = input("Посада: ")

# Формування ініціалів
initials = first_name[0].upper() + ". " + patronymic[0].upper() + "."

# Формування повного рядка
result = f"{initials} {last_name}, {position}"

# Вивід результату
print(result)

# %% [markdown]
# **Завдання для самостійного виконання 5**
#
# Виправ цю програму, так, щоб вона приймала вхідні дані в наступному форматі:
# Олексій Костянтинович Романов бугалтер

# %%
data = input("Введіть ім'я, по батькові, прізвище та посаду: ")

parts = data.split()

first_name = parts[0]
patronymic = parts[1]
last_name = parts[2]
position = " ".join(parts[3:])

initials = first_name[0].upper() + ". " + patronymic[0].upper() + "."

result = f"{initials} {last_name}, {position}"

print(result)
# Out:
# Введіть ім'я, по батькові, прізвище та посаду: Микита Миколайович Бондар фармацевт
# М. М. Бондар, фармацевт

# %% [markdown]
# **Завдання 6**
#
# Напишіть програму, яка отримує на вхід рядок тексту і букву, а потім визначає, чи зустрічається дана буква (в будь-якому регістрі) у тексті. Як відповідь програма має виводити True або False.
#
# Виконайте приклад нижче

# %%
# Ввід тексту та букви
text = input("Введіть текст: ")
letter = input("Введіть букву: ")

# Перевірка наявності букви у тексті (незалежно від регістру)
result = letter.lower() in text.lower()

# Вивід результату
print(result)

# %% [markdown]
# **Завдання для самостійного виконання 6**
#
# Виправ цю програму так, щоб вона перевіряла, чи зустрічається в тексті велика або маленька «O»

# %%
text = input("Введіть текст: ")

result = "о" in text.lower()

print(result)
# Out:
# Введіть текст: Хор
# True

# %% [markdown]
# **Завдання 7**
#
# Напишіть програму, яка визначає, чи є введена користувачем буква голосною. Як відповідь програма виводить True або False, літери можуть бути як у верхньому, так і в нижньому регістрі.
#
# Виконайте код нижче:

# %%
# Ввід літери
letter = input("Введіть одну літеру: ")

# Список голосних українських літер
vowels = "аеєиіїоуюяАЕЄИІЇОУЮЯ"

# Перевірка
is_vowel = letter in vowels

# Вивід результату
print(is_vowel)

# %% [markdown]
# **Завдання для самостійного виконання 7**
#
# Виправ цю програму так, щоб вона повертала true, якщо введена літера є великою приголосною

# %%
letter = input("Введіть одну літеру: ")

consonants = "БВГҐДЖЗЙКЛМНПРСТФХЦЧШЩ"

is_consonant = letter in consonants

print(is_consonant)
# Out:
# Введіть одну літеру: В
# True

# %% [markdown]
# **Завдання 8**
#
# Напишіть програму, яка приймає на вхід рядок тексту і підрядок, а потім виводить індекси першого входження підрядка з початку і з кінця рядка (без урахування регістру).
#
# Приклад введення:
#
# Шість шустрий мишат в очеретах шурхотять
# шу

# %%
# Ввід тексту та підрядка
text = input("Введіть текст: ")
substring = input("Введіть підрядок: ")

# Перетворення обох рядків до нижнього регістру
text_lower = text.lower()
substring_lower = substring.lower()

# Індекси першого входження з початку і з кінця
first_index = text_lower.find(substring_lower)
last_index = text_lower.rfind(substring_lower)

# Вивід результату
print(first_index)
print(last_index)

# %% [markdown]
# **Завдання для самостійного виконання 8**
#
# Знайдіть в цьому рядку індекс першого входження з кінця літери “y”

# %%
text = input("Введіть рядок: ")

index = text.rfind("у")

print(index)
# Out:
# Введіть рядок: Український урок
# 12

# %% [markdown]
# **Завдання для самостійного виконання 9**
#
# Напишіть програму для підрахунку кількості пробілів і непробільних символів у введеному користувачем рядку.

# %%
text = input("Введіть рядок: ")

spaces = text.count(" ")

non_spaces = len(text) - spaces

print("Кількість пробілів:", spaces)
print("Кількість непробільних символів:", non_spaces)
# Out:
# Введіть рядок: Добре і весело
# Кількість пробілів: 2
# Кількість непробільних символів: 12

# %% [markdown]
# **ІДЗ**
#
# **Виконайте завдання свого варіанту**
# 1. Даний рядок. Вивести його три рази через кому і показати кількість символів в ньому.
#
# 2. Даний рядок. Вивести перший, останній і середній (якщо він є) символи.
#
# 3. Даний рядок. Вивести перші три символи і останні три символи, якщо довжина рядка більше 5. Інакше вивести перший символ стільки раз, яка довжина рядка.
#
# 4. Даний рядок. Замінити символи на парних місцях парними числами, непарні символи залишити без змін.
#
# 5. Даний рядок. Показати номери символів, які збігаються з останнім символом рядка.
#
# 6. Даний рядок. Показати третій, шостий, дев'ятий і так далі символи.
#
# 7. Даний рядок. Визначте загальну кількість символів '+' і '-' в ніому. А так же скільки таких символів, після яких слід цифра нуль.
#
# 8. Даний рядок. Визначте, який символ в ній зустрічається раніше: 'x' або 'w'. Якщо якогось із символів немає, вивести повідомлення про це.
#
# 9. Данідва рядки. Вивести більший по довжині рядок стільки раз, на скільки символів відрізняються рядки.
#
# 10. Даний рядок. Якщо він починається на 'abc', то замінити їх на 'www', інакше додати в кінець рядка 'zzz'.
#
# 11. Даний рядок. Якщо його довжина більше 10, то залишити в рядку тільки перші 6 символів, інакше доповнити рядок символами 'o' до довжини 12.
#
# 12. Даний рядок. Розділити рядок на фрагменти по три поспіль символыв. У кожному фрагменті середній символ замінити на випадковий символ, який не збігається ні з одним з символів цього фрагмента. Показати фрагменти, впорядковані за алфавітом.
#
# 13. Даний рядок. Замінити кожен парний символ або на 'a', якщо символ НЕ дорівнює 'a' або 'b', або на 'c' в іншому випадку.
#
# 14. У рядку знайти кількість цифр.
# 15. Даний рядок. Визначити, чи містить рядок тільки символи 'a', 'b', 'c' чи ні.
#
# 16. Замініть в рядку всі входження 'word' на 'letter'.

# %%
text = input("Введіть рядок: ")

x_index = text.find("x")
w_index = text.find("w")

if x_index == -1 and w_index == -1:
    print("Символів 'x' і 'w' немає")
elif x_index == -1:
    print("Символу 'x' немає")
elif w_index == -1:
    print("Символу 'w' немає")
elif x_index < w_index:
    print("Символ 'x' зустрічається раніше")
else:
    print("Символ 'w' зустрічається раніше")
# Out:
# Введіть рядок: Expensive world
# Символ 'x' зустрічається раніше
